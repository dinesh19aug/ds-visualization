# %%
import numpy as np
import pandas as pd

# %%
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)

# %%
print(df_can.columns)
df_can.head
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')
# <bound method NDFrame.head of            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# ...

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %% [markdown]
# ### Drop the irrelevant columns

# %%
df_can = df_can.drop(columns=['Type', 'Coverage'], axis=1)

# %% [markdown]
# ### Make country as index column

# %%
df_can=df_can.set_index(['OdName'])

# %%
df_can
# Out:
#                 AREA AreaName   REG             RegName  DEV  \
# OdName
# Afghanistan      935     Asia  5501       Southern Asia  902
# Albania          908   Europe   925     Southern Europe  901
# Algeria          903   Africa   912     Northern Africa  902
# American Samoa   909  Oceania   957           Polynesia  902
# Andorra          908   Europe   925     Southern Europe  901
# ...              ...      ...   ...                 ...  ...
# Viet Nam         935     Asia   920  South-Eastern Asia  902
# Western Sahara   903   Africa   912     Northern Africa  902
# Yemen            935     Asia   922        Western Asia  902
# Zambia           903   Africa   910      Eastern Africa  902
# Zimbabwe         903   Africa   910      Eastern Africa  902
#
#                            DevName  1980  1981  1982  1983  ...  2004  2005  \
# OdName                                                      ...
# Afghanistan     Developing regions    16    39    39    47  ...  2978  3436
# ...

# %%
df_can.rename_axis(['Country'])
# Out:
#                 AREA AreaName   REG             RegName  DEV  \
# Country
# Afghanistan      935     Asia  5501       Southern Asia  902
# Albania          908   Europe   925     Southern Europe  901
# Algeria          903   Africa   912     Northern Africa  902
# American Samoa   909  Oceania   957           Polynesia  902
# Andorra          908   Europe   925     Southern Europe  901
# ...              ...      ...   ...                 ...  ...
# Viet Nam         935     Asia   920  South-Eastern Asia  902
# Western Sahara   903   Africa   912     Northern Africa  902
# Yemen            935     Asia   922        Western Asia  902
# Zambia           903   Africa   910      Eastern Africa  902
# Zimbabwe         903   Africa   910      Eastern Africa  902
#
#                            DevName  1980  1981  1982  1983  ...  2004  2005  \
# Country                                                     ...
# Afghanistan     Developing regions    16    39    39    47  ...  2978  3436
# ...

# %%
df_migration_columns = df_can.iloc[:,6:]

# %%
df_can["Total"]= df_migration_columns.sum(axis=1)

# %%
df_can
# Out:
#                 AREA AreaName   REG             RegName  DEV  \
# OdName
# Afghanistan      935     Asia  5501       Southern Asia  902
# Albania          908   Europe   925     Southern Europe  901
# Algeria          903   Africa   912     Northern Africa  902
# American Samoa   909  Oceania   957           Polynesia  902
# Andorra          908   Europe   925     Southern Europe  901
# ...              ...      ...   ...                 ...  ...
# Viet Nam         935     Asia   920  South-Eastern Asia  902
# Western Sahara   903   Africa   912     Northern Africa  902
# Yemen            935     Asia   922        Western Asia  902
# Zambia           903   Africa   910      Eastern Africa  902
# Zimbabwe         903   Africa   910      Eastern Africa  902
#
#                            DevName  1980  1981  1982  1983  ...  2005  2006  \
# OdName                                                      ...
# Afghanistan     Developing regions    16    39    39    47  ...  3436  3009
# ...

# %%
import matplotlib.pyplot as plt

# %%
years = list(df_can.iloc[:,6:-1].columns)

# %%
df_can.loc['Haiti', years].plot(kind = 'line')
plt.title('Immigration from Haiti')
plt.xlabel('Years')
plt.ylabel('Number of Immigrants')
plt.show()
